# %% [markdown]
# ## **View Data**

# %%
import json
import requests
from PIL import Image
from io import BytesIO
from collections import defaultdict

def load_coco_captions_with_urls(annotation_file):
    with open(annotation_file, 'r') as f:
        coco = json.load(f)

    # Get image_id 
    id_to_url = {img['id']: img['coco_url'] for img in coco['images']}

    # image_url 
    captions_dict = defaultdict(list)
    for ann in coco['annotations']:
        image_id = ann['image_id']
        image_url = id_to_url.get(image_id)
        if image_url:
            captions_dict[image_url].append(ann['caption'])

    return captions_dict

# Load captions
annotation_file = 'captions_train2017.json'
captions_dict = load_coco_captions_with_urls(annotation_file)

# Display first two images and their captions
for image_url, captions in list(captions_dict.items())[:100]:
    # Download and show the image
    # response = requests.get(image_url)
    # image = Image.open(BytesIO(response.content))
    # image.show()

    # Print captions
    print(f"\nImage URL: {image_url}")
    for i, caption in enumerate(captions):
        print(f"Caption {i+1}: {caption}")
# Out:
# Image URL: http://images.cocodataset.org/train2017/000000203564.jpg
# Caption 1: A bicycle replica with a clock as the front wheel.
# Caption 2: The bike has a clock as a tire.
# Caption 3: A black metal bicycle with a clock inside the front wheel.
# Caption 4: A bicycle figurine in which the front wheel is replaced with a clock
#
# Caption 5: A clock with the appearance of the wheel of a bicycle
#
# Image URL: http://images.cocodataset.org/train2017/000000322141.jpg
# Caption 1: A room with blue walls and a white sink and door.
# Caption 2: Blue and white color scheme in a small bathroom.
# Caption 3: This is a blue and white bathroom with a wall sink and a lifesaver on the wall.
# Caption 4: A blue boat themed bathroom with a life preserver on the wall
# Caption 5: A bathroom with walls that are painted baby blue.
#
# Image URL: http://images.cocodataset.org/train2017/000000016977.jpg
# Caption 1: A car that seems to be parked illegally behind a legally parked car
# Caption 2: two cars parked on the sidewalk on the street
# Caption 3: City street with parked cars and a bench.
# Caption 4: Cars try to maneuver into parking spaces along a densely packed city street.
# Caption 5: A couple of cars parked in a busy street sidewalk.
#
# Image URL: http://images.cocodataset.org/train2017/000000106140.jpg
# Caption 1: A large passenger airplane flying through the air.
# Caption 2: There is a GOL plane taking off in a partly cloudy sky.
# Caption 3: An airplane that is, either, landing or just taking off.
# Caption 4: An red and white airplane is in the cloudy sky.
# Caption 5: A passenger plane taking off into the sky.
#
# Image URL: http://images.cocodataset.org/train2017/000000571635.jpg
# Caption 1: A bathroom with a toilet, sink, and shower.
# Caption 2: A full bathroom with a wicker laundry basket.
# Caption 3: A little bathrood decorated with many colorful objects
# Caption 4: A small bathroom containing a toilet and sink.
# Caption 5: Bathroom containing a toilet, a sink and a wicker basket.
#
# Image URL: http://images.cocodataset.org/train2017/000000301837.jpg
# Caption 1: A long empty, minimal modern skylit home kitchen.
# Caption 2: A picture of a modern looking kitchen area
#
# Caption 3: A narrow kitchen ending with a chrome refrigerator.
# Caption 4: A narrow kitchen is decorated in shades of white, gray, and black.
# Caption 5: a room that has a stove and a icebox in it
#
# Image URL: http://images.cocodataset.org/train2017/000000315702.jpg
# Caption 1: A bathroom sink with toiletries on the counter.
# Caption 2: A bathroom sink and various personal hygiene items.
# Caption 3: A messy bathroom countertop perched atop black cabinetry.
# Caption 4: A bathroom vanity with cabinets and basin sink and several grooming products scattered across it
# Caption 5: A bathroom sink cluttered with multiple personal care items.
#
# Image URL: http://images.cocodataset.org/train2017/000000189634.jpg
# Caption 1: This is an open box containing four cucumbers.
# Caption 2: An open food container box with four unknown food items.
# Caption 3: A small box filled with four green vegetables.
# Caption 4: An opened box of four chocolate bananas.
# Caption 5: An open box contains an unknown, purple object
#
# Image URL: http://images.cocodataset.org/train2017/000000472598.jpg
# Caption 1: An old-fashioned green station wagon is parked on a shady driveway.
# Caption 2: An old teal colored car parked on the street.
# Caption 3: A classic car sitting beside the road with a surfboard on top.
# Caption 4: An old green car parked on the side of the street.
# Caption 5: An antique, turquoise car is parked at the curb
#
# Image URL: http://images.cocodataset.org/train2017/000000162113.jpg
# Caption 1: A gas stove next to a stainless steel kitchen sink and countertop.
# Caption 2: A kitchen stove, sink, and counter with stuff on it.
# Caption 3: A kitchen with a stove, sink, and drying area.
# Caption 4: This is a kitchen with dishes and a silver sink.
# Caption 5: A kitchen with a stove, sick, and dishes
#
# Image URL: http://images.cocodataset.org/train2017/000000126657.jpg
# Caption 1: Several motorcycles riding down the road in formation.
# Caption 2: A group of motorcycle riders driving past buildings.
# Caption 3: A group of people are riding motorcycles on a road through a town.
# Caption 4: A group of motorcyclists are driving down the city street.
# Caption 5: A group of motorcycles drive down a city street.
#
# Image URL: http://images.cocodataset.org/train2017/000000285421.jpg
# Caption 1: A black cat is inside a white toilet.
# Caption 2: A black cat drinking water from a toilet
# Caption 3: A cat drinking water from a toilet in a bathroom.
# Caption 4: A cat puts her head inside of a toilet.
# Caption 5: A cat is drinking water out of a toilet.
#
# Image URL: http://images.cocodataset.org/train2017/000000071988.jpg
# Caption 1: A man in a wheelchair and another sitting on a bench that is overlooking the water.
# Caption 2: Two people sitting on dock looking at the ocean.
# Caption 3: Two older people sitting down in front of a beach.
# Caption 4: An old couple at the beach during the day.
# Caption 5: A person on a bench, and one on a wheelchair sitting by a seawall looking out toward the ocean
#
# Image URL: http://images.cocodataset.org/train2017/000000193622.jpg
# Caption 1: A man sits with a traditionally decorated cow
# Caption 2: A decorative man sits on the ground with a cow.
# Caption 3: A man sits next to his horse in an alley in costume.
# Caption 4: Guy and cow are sitting on the floor
# Caption 5: An Indian man in religious attire sitting with a decorated cow.
#
# Image URL: http://images.cocodataset.org/train2017/000000459912.jpg
# Caption 1: Rows of motor bikes and helmets in a city
# Caption 2: A lot of motorbikes line up down a busy street.
# Caption 3: Large set of motorcycles all lined up down a street.
# Caption 4: A large group of motorcycles lined up on the street.
# Caption 5: A series of motorbikes parked in a row on a street
#
# Image URL: http://images.cocodataset.org/train2017/000000548498.jpg
# Caption 1: A cute kitten is sitting in a dish on a table.
# Caption 2: A small white cat on a large bowl.
# Caption 3: A small kitten is sitting in a bowl.
# Caption 4: A cat is curled up in a bowl
# Caption 5: A kitten is sitting in a bowl on a table.
#
# Image URL: http://images.cocodataset.org/train2017/000000052087.jpg
# Caption 1: A man getting a drink from a water fountain that is a toilet.
# Caption 2: A boy drinking water from a toilet water fountain.
# Caption 3: A young man drinking from a water fountain in the shape of a toilet.
# Caption 4: A young person has his face close to the toilet bowl.
# Caption 5: A man taking a drink from a water fountain.
#
# Image URL: http://images.cocodataset.org/train2017/000000119964.jpg
# Caption 1: A person holding a skateboard overlooks a dead field of crops.
# Caption 2: A person sits on a patch of grass observing the scenery.
# Caption 3: A person holding a skate board sitting in an empty open field.
# Caption 4: A child with a skateboard sitting on the grass and looking at an empty field
# Caption 5: A skateboarder sitting on the edge of an open field.
#
# Image URL: http://images.cocodataset.org/train2017/000000230610.jpg
# Caption 1: A bathroom with a sink and shower curtain with a map print.
# Caption 2: A small and crowded bathroom with little furnishing
# Caption 3: A small bathroom with a shower curtain with the NYC Subway map on it.
# Caption 4: A bathroom with a map as a shower curtain.
# Caption 5: A bathroom with pedestal sink and mirror over it.
#
# Image URL: http://images.cocodataset.org/train2017/000000226419.jpg
# Caption 1: A random plane in the sky flying alone
# Caption 2: An airplane flying high in the blue sky.
# Caption 3: A silver color jet flying through the clear sky.
# Caption 4: An airplane with the letters 'MT' on it, flying in the sky.
# Caption 5: A very large plane is flying through the sky.
#
# Image URL: http://images.cocodataset.org/train2017/000000218026.jpg
# Caption 1: A brown and black horse in the middle of the city eating grass.
# Caption 2: Two horses eating grass near a parking lot.
# Caption 3: Two horses standing in a field across the stre.et from a building
# Caption 4: Two mules eating grass in a parking lot in front of a hotel.
# Caption 5: Two horses eat grass next to a group of parked cars.
#
# Image URL: http://images.cocodataset.org/train2017/000000352538.jpg
# Caption 1: A brown purse is sitting on a green bench.
# Caption 2: a brown purse abandoned on a green bench.
# Caption 3: A woman's purse sitting on a park bench.
# Caption 4: A leather purse laying on it's side on a green metal bench.
# Caption 5: A purse sits alone on a park bench.
#
# Image URL: http://images.cocodataset.org/train2017/000000202913.jpg
# Caption 1: Half of a white cake with coconuts on top.
# Caption 2: The coconut cake on a red plate is half gone.
# Caption 3: A half eaten dessert cake sitting on a cake plate.
# Caption 4: A half eaten cake with coconut shavings and creme filling.
# Caption 5: Half of a cake sits on a plate.
#
# Image URL: http://images.cocodataset.org/train2017/000000202658.jpg
# Caption 1: An old toilet with a hello kitty cover top.
# Caption 2: A toilet with a Hello Kitty symbol on it.
# Caption 3: A toilette with a pink hello kitty toilette seat cover.
# Caption 4: A toilet with a Hello Kitty seat sitting in a room.
# Caption 5: A broken toilet bowl with  a Hello Kitty toilet seat cover.
#
# Image URL: http://images.cocodataset.org/train2017/000000079472.jpg
# Caption 1: Office space with office equipment on desk top.
# Caption 2: A hope office setup of computers and printers.
# Caption 3: a home office with laptop, printer, scanner, and extra monitor
# Caption 4: The computer desk in the corner is by a window.
# Caption 5: A laptop, monitor, printer and tablet on a desk.
#
# Image URL: http://images.cocodataset.org/train2017/000000346071.jpg
# Caption 1: Two husky's hanging out of the car windows.
# Caption 2: Dogs stick their heads out of car windows
# Caption 3: Two husky dogs ride in a car with their heads hanging out windows.
# Caption 4: Two happy dogs have their head out the car window.
# Caption 5: Some dogs stick their heads out the car window.
#
# Image URL: http://images.cocodataset.org/train2017/000000006672.jpg
# Caption 1: The back door with a window in the kitchen.
# Caption 2: The kitchen has a white door with a window.
# Caption 3: A kitchen door next to a kitchen sing and counter top.
# Caption 4: A sink next to a large white door
# Caption 5: A door for exiting and entering the house in the kitchen.
#
# Image URL: http://images.cocodataset.org/train2017/000000419074.jpg
# Caption 1: Jet liner flying off into the distance on an overcast day
# Caption 2: An airplane flying away in a cloudy sky.
# Caption 3: A plane that is flying in a clear blue sky.
# Caption 4: An airplane flying away in the cloudy sky.
# Caption 5: Four engine plane flying in lightly overcast sky.
#
# Image URL: http://images.cocodataset.org/train2017/000000382406.jpg
# Caption 1: A woman is walking a dog in the city.
# Caption 2: A woman and her dog walking down a sidewalk next to a fence with some flowers.
# Caption 3: A woman walking her dog on the sidewalk.
# Caption 4: A woman walks her dog along a city street.
# Caption 5: A woman walks her dog on a city sidewalk.
#
# Image URL: http://images.cocodataset.org/train2017/000000175948.jpg
# Caption 1: A tiny bathroom with only a toilet and a shelf.
# Caption 2: Small bathroom with a toilet and a sink.
# Caption 3: A narrow bathroom has a white door on its side
# Caption 4: Rather narrow bath room that appears to be being remodeled.
# Caption 5: Unfinished bathroom with broken toilet next to a bookshelf.
#
# Image URL: http://images.cocodataset.org/train2017/000000573223.jpg
# Caption 1: A little girl in a public bathroom for kids.
# Caption 2: A girl standing next to a toilet in a bathroom.
# Caption 3: Little girl in blue dress standing in a bathroom.
# Caption 4: An adorable little girl in a blue dress stands in a restroom.
# Caption 5: A little girl in a blue dress stands in a bathroom.
#
# Image URL: http://images.cocodataset.org/train2017/000000402514.jpg
# Caption 1: A picture of a man playing a violin in a kitchen.
# Caption 2: A man is playing violin in his kitchen
# Caption 3: A man is playing a fiddle in his kitchen.
# Caption 4: A man plays the violin in a home.
# Caption 5: An old man playing violin in a kitchen.
#
# Image URL: http://images.cocodataset.org/train2017/000000407286.jpg
# Caption 1: A trio of dogs sitting in their owner's lap in a red convertible.
# Caption 2: Three little dogs looking out a car window while sitting on a woman's lap.
# Caption 3: A woman driver has three dogs in the seat with her.
# Caption 4: A woman and her three dogs in a car.
# Caption 5: Three dogs on the lap of a woman in the driver's seat of a convertible.
#
# Image URL: http://images.cocodataset.org/train2017/000000082673.jpg
# Caption 1: A small car is parked in front of a scooter
# Caption 2: A scooter is parked behind a red car.
# Caption 3: A small car parked in by a vespa.
# Caption 4: A bus rides by a small car parked in front of a motor scooter
# Caption 5: A small car sits parked in front of a scooter.
#
# Image URL: http://images.cocodataset.org/train2017/000000141172.jpg
# Caption 1: A door with a sticker of a cat door on it
# Caption 2: A blue door with a painting of a cat's rear end entering thru a cat door.
# Caption 3: A blue door with a picture of a cat door with cats backside hanging out on it.
# Caption 4: A picture of a cat door is on the bottom corner of a blue door.
# Caption 5: A painting on a door of a cat going through a cat door.
#
# Image URL: http://images.cocodataset.org/train2017/000000104326.jpg
# Caption 1: A pinewood and green modern themed kitchen area.
# Caption 2: A kitchen and dining room area with a large window.
# Caption 3: A green kitchen with wooden counters and bright lights.
# Caption 4: A bright room with green walls and cabinets.
# Caption 5: An empty kitchen area painted green with bulbous lights.
#
# Image URL: http://images.cocodataset.org/train2017/000000581177.jpg
# Caption 1: A kitchen is shown with wooden cabinets and a wooden celling.
# Caption 2: A recently remodeled kitchen with marble and wooden furnishings.
# Caption 3: Well kept kitchen with marble counter tops and stainless steel fridge
# Caption 4: A beautiful new kitchen with natural wood cabinets.
# Caption 5: A neat, wood filled kitchen is photographed as if for a real estate ad.
#
# Image URL: http://images.cocodataset.org/train2017/000000267802.jpg
# Caption 1: A group of people riding mopeds in a busy street.
# Caption 2: People riding bikes and cars down the street.
# Caption 3: Motorists and bicyclists in a busy city square.
# Caption 4: A crowded city street filled with traffic and bicycles.
# Caption 5: An Asian intersection is full of mopeds and motorcycles.
#
# Image URL: http://images.cocodataset.org/train2017/000000208408.jpg
# Caption 1: A person walking in the rain on the sidewalk.
# Caption 2: A person walking through the rain with an umbrella.
# Caption 3: A person walking in the rain while holding an umbrella.
# Caption 4: A man walks down the strip as it rains.
# Caption 5: A European street scene with a person and vehicles.
#
# Image URL: http://images.cocodataset.org/train2017/000000560591.jpg
# Caption 1: a modern flush toilet in a bathroom with tile.
# Caption 2: A toilet and trashcan in a white bathroom.
# Caption 3: A white toilet sits on a tile floor.
# Caption 4: A toilet in a bathroom that is next to a trash can
# Caption 5: White toilet by built-in shelves in a tiled bathroom.
#
# Image URL: http://images.cocodataset.org/train2017/000000507362.jpg
# Caption 1: Fog is in the air at an intersection with several traffic lights.
# Caption 2: An intersection during a cold and foggy night.
# Caption 3: Empty fog covered streets in the night amongst traffic lights.
# Caption 4: City street at night with several stop lights.
# Caption 5: It is a foggy night by a traffic light.
#
# Image URL: http://images.cocodataset.org/train2017/000000057429.jpg
# Caption 1: An airplane with its landing wheels out landing.
# Caption 2: A plane that is taking off at an airport
# Caption 3: A man takes a picture of an airplane taking off.
# Caption 4: A large jet takes off from an airport runway.
# Caption 5: The airplane is taking off on the runway at the airport.
#
# Image URL: http://images.cocodataset.org/train2017/000000153184.jpg
# Caption 1: Little birds sitting on the shoulder of a giraffe.
# Caption 2: The top of a giraffe's head has birds on it.
# Caption 3: Three birds sit on the back of a giraffe.
# Caption 4: A giraffe with 3 birds on his fur.
# Caption 5: A flock of birds sits on top of a large giraffe.
#
# Image URL: http://images.cocodataset.org/train2017/000000571970.jpg
# Caption 1: a man with a bike at a marina
# Caption 2: A man stands next to his bike at the marina.
# Caption 3: an old man standing next to a bike and a chain fence.
# Caption 4: A man holding some break standing by a bicycle.
# Caption 5: A man who is standing next to his bicycle.
#
# Image URL: http://images.cocodataset.org/train2017/000000133680.jpg
# Caption 1: A man is sitting on a bench next to a bike.
# Caption 2: A man is sitting on a bench next to a bicycle.
# Caption 3: A man sits on a street bench by a bike.
# Caption 4: Black man sitting on a bench behind a personal bicycle.
# Caption 5: A man is sitting in a busy area with his bike.
#
# Image URL: http://images.cocodataset.org/train2017/000000139011.jpg
# Caption 1: People are waiting for the bus near a bus stop.
# Caption 2: A crowd of people are waiting to get on a red bus.
# Caption 3: A crowd of people get ready to board a bus in the city.
# Caption 4: Large group of people waiting for a train.
# Caption 5: People are waiting in a city area to board a bus.
#
# Image URL: http://images.cocodataset.org/train2017/000000505386.jpg
# Caption 1: four urinals in a public restroom with a window
# Caption 2: A bathroom with four urinals on the wall.
# Caption 3: An old bathroom with a row of urinals.
# Caption 4: A row of urinals in with an open window above them.
# Caption 5: A row of urinals stand beneath a open window.
#
# Image URL: http://images.cocodataset.org/train2017/000000107990.jpg
# Caption 1: A small child climbs atop a large motorcycle
# Caption 2: A young boy riding a motorcycle next to a silver car.
# Caption 3: A little baby is sitting on a huge motorcycle.
# Caption 4: A little boy sitting alone on a motorcycle.
# Caption 5: A toddler sitting on a motorcycle in a parking lot.
#
# Image URL: http://images.cocodataset.org/train2017/000000527510.jpg
# Caption 1: A large U.S Air Force plain sits on an asphalt ramp.
# Caption 2: A large propeller airplane sitting on a tarmac.
# Caption 3: A large military plane parked in the landing area.
# Caption 4: A U.S. Air Force plane sits on display.
# Caption 5: A picture of a plane in a runway.
#
# Image URL: http://images.cocodataset.org/train2017/000000005247.jpg
# Caption 1: A black and white photo of an older man skiing.
# Caption 2: Two people on the snow for cross country skiing.
# Caption 3: The old man cross country skis through the forest.
# Caption 4: A younger man and an older man skiing in the forest.
# Caption 5: Two people on skis going through the woods.
#
#
# Image URL: http://images.cocodataset.org/train2017/000000107960.jpg
# Caption 1: Riding a motorcycle down a street that has no one else on it.
# Caption 2: The view from a motorcyclist's point of view, looking down a street.
# Caption 3: A man rides a motorcycle down an empty street next to houses.
# Caption 4: The view of the street from the perspective of the rider of a motorcycle
# Caption 5: A motorcycle moves forward down an empty street.
#
# Image URL: http://images.cocodataset.org/train2017/000000410627.jpg
# Caption 1: The young man is stirring his pot of food with a wooden spoon.
# Caption 2: A man enjoys cooking food in a pan
# Caption 3: A smiling man is cooking in his kitchen.
# Caption 4: A man smiles as he stirs his food in the pot.
# Caption 5: A boy smiles while holding a pot and spoon.
#
# Image URL: http://images.cocodataset.org/train2017/000000232223.jpg
# Caption 1: A fighter jet is flying at a fast speed.
# Caption 2: A fighter jet soars up into a blue sky.
# Caption 3: An old military jet fighter climbing in altitude.
# Caption 4: A fighter jet flying through the sky with smoke coming off of it.
# Caption 5: A figher jet creating condensation flying through the blue sky.
#
# Image URL: http://images.cocodataset.org/train2017/000000022793.jpg
# Caption 1: A public bathroom with a bunch of urinals.
# Caption 2: A picture of a woman hangs on the wall above the urinals.
# Caption 3: A men's restroom with a poster of a woman over the urinals.
# Caption 4: White tiled bathroom with line of tiles and Asian female poster on the wall
# Caption 5: A mens restroom is lined up with urinals.
#
# Image URL: http://images.cocodataset.org/train2017/000000436456.jpg
# Caption 1: The airplane is on the runway with two young men standing by.
# Caption 2: Two men walking the tarmac of an airport.
# Caption 3: Two men at on an airport tarmac.
#
# Caption 4: Two young men walking down a runway toward an airplane.
# Caption 5: Young men are preparing to board a small passenger plane.
#
# Image URL: http://images.cocodataset.org/train2017/000000368402.jpg
# Caption 1: The woman in the kitchen is holding a huge pan.
# Caption 2: A chef carrying a large pan inside of a kitchen.
# Caption 3: A woman is holding a large pan in a kitchen.
# Caption 4: A woman cooking in a kitchen with granite counters.
# Caption 5: A woman cooking in her kitchen with a black pan.
#
# Image URL: http://images.cocodataset.org/train2017/000000135161.jpg
# Caption 1: A toilet sits next to a window and in front of a shower.
# Caption 2: A bathroom with only a toilet and tub with the wall covered in plastic
# Caption 3: A photograph of a bathroom undergoing some renovations.
# Caption 4: A bathroom being renovated featuring a toilette and shower.
# Caption 5: A bathroom in the middle of a reconstruction phase.
#
# Image URL: http://images.cocodataset.org/train2017/000000178761.jpg
# Caption 1: A dog and a goat with their noses touching at fence.
# Caption 2: A dog greets a sheep that is in a sheep pen.
# Caption 3: Two animals get close through a fence.
# Caption 4: A sheep and a dog touching noses through a fence.
# Caption 5: a couple of animals that are beside a fence
#
# Image URL: http://images.cocodataset.org/train2017/000000491000.jpg
# Caption 1: Pedestrians walking down a sidewalk next to a small street.
# Caption 2: People walking on a city street with light traffic.
# Caption 3: A city street with people walking and vehicles on the road.
# Caption 4: A scenic photograph of an urban street with people and traffic.
# Caption 5: Pedestrians are strolling along a city sidestreet in a touristy neighborhood.
#
# Image URL: http://images.cocodataset.org/train2017/000000538092.jpg
# Caption 1: A man standing in a kitchen while closing a cupboard door.
# Caption 2: A man standing in kitchen surrounded by items.
# Caption 3: A kitchen area with a cooler and container stacked on the floor and a man getting an item out of a cabinet.
# Caption 4: A man holding a cabinet in a kitchen.
# Caption 5: a man stocking up his kitchen with groceries
#
# Image URL: http://images.cocodataset.org/train2017/000000205577.jpg
# Caption 1: A photograph of a kitchen inside a house.
# Caption 2: This is an apartment kitchen with white cabinets and appliances.
# Caption 3: A shot of a kitchen with a microwave, sink, dishwasher, and refrigerator.
# Caption 4: A kitchen with a refrigerator, microwave, dishwasher and sink.
# Caption 5: A kitchen with a sink, dishwasher, microwave and refrigerator.
#
# Image URL: http://images.cocodataset.org/train2017/000000508672.jpg
# Caption 1: a bike leaning on a metal fence next to some flowing water.
# Caption 2: A bicycle parked next to a flooded river
# Caption 3: A bicycle chained to a rail near a flooded area.
# Caption 4: A bicycle leans against a fence near some flood waters.
# Caption 5: A bicycle parked on a rail next to some flooding water.
#
# Image URL: http://images.cocodataset.org/train2017/000000334015.jpg
# Caption 1: a small toilet stall with a toilet brush and 3 rolls of toilet paper
# Caption 2: A clean, European toilet with toilet paper and cleaning brush.
# Caption 3: A public toilet stall with toilet paper and a cleaning brush.
# Caption 4: An empty, clean toilet stall with a stack of toilet paper.
# Caption 5: There is a white toilet in a very narrow bathroom.
#
# Image URL: http://images.cocodataset.org/train2017/000000027842.jpg
# Caption 1: A dual sink vanity with mirrors above the sinks.
# Caption 2: A long marble like bath room vanity with a stool, two sink basins with mirrors and lights over them
# Caption 3: A double sink with mirrors and a stool underneath it.
# Caption 4: There are two sinks in the clean bathroom.
# Caption 5: A bathroom with his and her mirrors and sinks.
#
# Image URL: http://images.cocodataset.org/train2017/000000358606.jpg
# Caption 1: A fireplace with a fire built in it.
# Caption 2: A living room containing a modern fireplace and miscellaneous items
# Caption 3: A lit fire place in a living room next to a TV.
# Caption 4: A brick fireplace with fire adorned with knick-knacks.
# Caption 5: A living room, with fireplace, television, and throw rug.
#
# Image URL: http://images.cocodataset.org/train2017/000000567730.jpg
# Caption 1: The sign of a restaurant in the outside of the store.
# Caption 2: A sign on a building advertising an Italian restaurant.
# Caption 3: A sign for an Italian restaurant hangs outside a building.
# Caption 4: Italian Reaffaello restaurant sign at front of building.
# Caption 5: A sign outside of a restaurant for Italian food.
#
# Image URL: http://images.cocodataset.org/train2017/000000061259.jpg
# Caption 1: an airport with one plane flying away and the other sitting on the runway
# Caption 2: jumbo jet sits on the tarmac while another takes off
# Caption 3: A Virgin Australia airline on the tarmac.
# Caption 4: Virgin sponsored airplane parked with a plane leaving in the background.
# Caption 5: One airplane is taking off from an airport while others are parked.
#
# Image URL: http://images.cocodataset.org/train2017/000000554037.jpg
# Caption 1: a counter with vegetables, knife and cutting board on it.
# Caption 2: asparragus, lemons and a bowl of rice on a counter top
# Caption 3: The preparation of salmon, asparagus and lemons.
# Caption 4: Cooking table with assorted fish and lemons with asparagus.
# Caption 5: A kitchen counter with cutting board, knife and food.
#
# Image URL: http://images.cocodataset.org/train2017/000000005394.jpg
# Caption 1: A boat that looks like a car moves through the water.
# Caption 2: A car modified to drive in the water on a lake.
# Caption 3: A car modified to be a boat on the water.
# Caption 4: A picture of a boat that looks like a car in the water.
# Caption 5: a car that has been converted into a boat floating on water
#
# Image URL: http://images.cocodataset.org/train2017/000000455384.jpg
# Caption 1: A delivery truck with an advertisement for Entourage.
# Caption 2: A large van features an ad for a television show.
# Caption 3: A truck with an ad for a television show painted on its side
# Caption 4: A large delivery truck with an advertisement painted on it's side.
# Caption 5: An entourage decorated van is parked on the side of the road.
#
# Image URL: http://images.cocodataset.org/train2017/000000249352.jpg
# Caption 1: A black and white toilet with a plunger.
# Caption 2: A toilet has a rug, and a plunger next to it.
# Caption 3: A small stall with large tiles, a toilet and two plungers
# Caption 4: A small restroom with a single toilet and wooden toilet seat.
# Caption 5: A toilet, plunger and rug in a tiled bathroom stall.
#
# Image URL: http://images.cocodataset.org/train2017/000000348306.jpg
# Caption 1: A bike leaning against a sign in Scotland.
# Caption 2: A bike in front of a scenic welcome sign.
# Caption 3: a welcome to Scotland sign with a bicycle leaning on it
# Caption 4: Bicycle leaning up against a welcome to Scotland sign.
# Caption 5: A sign for a village in Scotland with a bicycle in front of it.
#
# Image URL: http://images.cocodataset.org/train2017/000000475593.jpg
# Caption 1: Women father around a desk and machinery in a factory.
# Caption 2: A photo set of two women at work
# Caption 3: Women working in a commercial bakery or kitchen.
# Caption 4: Two old photos with women in a kitchen.
# Caption 5: two women in white work at an industrial kitchen counter and stove
#
# Image URL: http://images.cocodataset.org/train2017/000000145523.jpg
# Caption 1: A few items sit on top of a toilet in a bathroom stall.
# Caption 2: A dirty toilet in a small bathroom.with items on top.
# Caption 3: A toilet seat is left open inside of a bathroom.
# Caption 4: A dirty toilet in a small cramped space.
# Caption 5: A photo of a toilet with items on the tank.
#
# Image URL: http://images.cocodataset.org/train2017/000000143370.jpg
# Caption 1: A bathroom with a poster of an ugly face above the toilette.
# Caption 2: A bathroom with a white toilet and sink.
# Caption 3: Large bathroom with light flowing in the window.
# Caption 4: A small bathroom with a toilet by the window and a pedestal sink with a mirrored medicine cabinet over it
# Caption 5: A bathroom with a toilet and a sink.
#
# Image URL: http://images.cocodataset.org/train2017/000000279806.jpg
# Caption 1: A dirt bike rider doing a stunt jump in the air
# Caption 2: A man riding a dirt bike becomes airborne.
# Caption 3: A motorcyclist is in mid air hanging on to the handlebars.
# Caption 4: A person performs a stunt jump on a motorcycle.
# Caption 5: Daring guy does tricks mid air on motorcycle
#
# Image URL: http://images.cocodataset.org/train2017/000000059171.jpg
# Caption 1: A couple of birds fly through a blue cloudy sky.
# Caption 2: Group of three people sailing kites up in the sky.
# Caption 3: A beautiful blue and pink sky overlooking the beach.
# Caption 4: Group of people are flying kites on the beach.
# Caption 5: This is a gorgeous sunset at a beach with a parasailor in the distance.
#
# Image URL: http://images.cocodataset.org/train2017/000000369826.jpg
# Caption 1: A picture advertising Arizona tourism in an airport
# Caption 2: A television that is sitting next to signs
# Caption 3: A television is shown in the middle of a baggage claim area.
# Caption 4: An airport terminal has a big screen displaying an ad for Arizona.
# Caption 5: A flat screen TV with a picture of a person jumping on it.
#
# Image URL: http://images.cocodataset.org/train2017/000000400552.jpg
# Caption 1: A variety of pots are stored in a nook by a fireplace.
# Caption 2: A room contains baskets and has a fireplace.
# Caption 3: A room filled with clutter and a fireplace.
# Caption 4: A small living room with a fireplace and work baskets.
#
# Caption 5: A room with a fir place and several baskets and a bench in the background.
#
# Image URL: http://images.cocodataset.org/train2017/000000238836.jpg
# Caption 1: A car is stopped at a red light
# Caption 2: The car is at the intersection while the sun is setting.
# Caption 3: A truck nears a stop light in rainy weather.
# Caption 4: A car is at a red light in the rain.
# Caption 5: An intersection with a red traffic light and a vehicle.
#
# Image URL: http://images.cocodataset.org/train2017/000000264461.jpg
# Caption 1: A bathroom with a traditional toilet next to a floor toilet.
# Caption 2: A squat toilet and a Western toilet are next to each other.
# Caption 3: Mans bathroom with two visible fixtures, trash basket and plunger in sight.
# Caption 4: A toilet stall, complete with two clean toilets.
# Caption 5: A bathroom with an odd toilette next to a normal toilette.
#
# Image URL: http://images.cocodataset.org/train2017/000000342387.jpg
# Caption 1: A group of people preparing food in a kitchen.
# Caption 2: Group of people all sorting vegetables in a line.
# Caption 3: Six different people in aprons and hats preparing vegetables
# Caption 4: A group of people are in a line working on green vegetables.
# Caption 5: A team of chefs work together to prepare a meal.
#
# Image URL: http://images.cocodataset.org/train2017/000000488327.jpg
# Caption 1: Posted signs point the way through a parking garage.
# Caption 2: Three traffic signs at the entrance of a parking garage.
# Caption 3: Three road signs posted in a parking garage.
# Caption 4: This is a parking garage with several signs.
# Caption 5:  directing signs in front of a parking garage
#
# Image URL: http://images.cocodataset.org/train2017/000000540860.jpg
# Caption 1: A green car on display next to a busy street.
# Caption 2: A sculpture of a green hot rod on a city sidewalk
# Caption 3: A sculpture of a hot rod sitting on a sidewalk.
# Caption 4: This is a city art piece of a small car.
# Caption 5: A small green vehicle model is on display next to a busy city street.
#
# Image URL: http://images.cocodataset.org/train2017/000000172851.jpg
# Caption 1: A large passenger jet taking off from an airport.
# Caption 2: A plane that just took off flying from an airport.
# Caption 3: The airplane has begun its ascent in the skies.
# Caption 4: A plane is shown taking off from an airstrip.
# Caption 5: An airplane is taking off at an airport.
#
# Image URL: http://images.cocodataset.org/train2017/000000486194.jpg
# Caption 1: Young woman carrying an opened umbrella in a city neighborhood.
# Caption 2: A woman walking while holding up a red umbrella
# Caption 3: A beautiful young lady walking in the rain while holding an umbrella.
# Caption 4: A woman holding a red umbrella traveling down a sidewalk.
# Caption 5: A young woman is carrying a red umbrella.
#
# Image URL: http://images.cocodataset.org/train2017/000000236148.jpg
# Caption 1: An older man backing up a truck with a bicycle in it's flat bed.
# Caption 2: A man looking out the back window of his truck.
# Caption 3: A man sits in the drivers seat of a truck.
# Caption 4: A man in a truck looks out his rear window.
# Caption 5: A man in a truck looking behind him.
#
# Image URL: http://images.cocodataset.org/train2017/000000115930.jpg
# Caption 1: A group of men standing in front of a bar having a conversation.
# Caption 2: Restaurant staff taking a break near the bar.
# Caption 3: Several men having a conversation at a restaurant.
# Caption 4: Three workers at a restaurant visiting with each other and customers.
# Caption 5: Three chefs talking to each other at a bar.
#
# Image URL: http://images.cocodataset.org/train2017/000000075663.jpg
# Caption 1: A children play area absent of any children.
# Caption 2: A craft supply room with craft supplies and containers.
# Caption 3: A work area room that is very very clean.
# Caption 4: A little children's classroom with materials and toys.
# Caption 5: A counter top that has bins and a bucket of glue on it.
# Caption 6: A toy kitchen with a small table phone hat and teddy bear, with assorted crafts on the counter.
#
# Image URL: http://images.cocodataset.org/train2017/000000352794.jpg
# Caption 1: Fruit in a jar filled with liquid sitting on a wooden table.
# Caption 2: Some yellow objects are floating in red liquid in a jar.
# Caption 3: There is a jar filled with an unknown liquid and solid.
# Caption 4: A jar of homemade sangria sitting on a table.
# Caption 5: A jar filled with liquid sits on a wood surface.
#
# Image URL: http://images.cocodataset.org/train2017/000000175954.jpg
# Caption 1: A work station in use inside an office.
# Caption 2: A desk inside a library with a computer and several papers on it.
# Caption 3: A workstation with a computer, notebook, and papers.
# Caption 4: An office desk with a lot of paperwork and a turned on computer
# Caption 5: The computer is turned on at the cluttered workstation.
#
# Image URL: http://images.cocodataset.org/train2017/000000484751.jpg
# Caption 1: Three computer screens showing a panoramic beach scene.
# Caption 2: Three computer screens at a desk show a panoramic view of the ocean.
# Caption 3: A desk with multiple computer screens forming one large screen.
# Caption 4: A computer desk with a triple monitor computer setup.
# Caption 5:  There are three tvs with a keyboard in front of it
#
# Image URL: http://images.cocodataset.org/train2017/000000457834.jpg
# Caption 1: Elephants are in a long line with people on top of them.
# Caption 2: Several people riding on the back of elephants
# Caption 3: A group of men riding elephants down a street surrounded by trees.
# Caption 4: People riding on top of elephants that are walking in a line across a road.
# Caption 5: There is a parade of elephants walking across the road.
#
# Image URL: http://images.cocodataset.org/train2017/000000412151.jpg
# Caption 1: A bicycle store shows two males leaning toward a bike.
# Caption 2: A man adjust a bicycle in a bike shop with a child.
# Caption 3: The bike shop employee is helping a customer.
# Caption 4: A man and a boy are talking about a bicycle in a store.
# Caption 5: Two people in a shop looking at a bike.
#
# Image URL: http://images.cocodataset.org/train2017/000000427091.jpg
# Caption 1: City traffic and pedestrians are headed in multiple directions on the street.
# Caption 2: A city street busy with many cars driving as well as pedestrians
# Caption 3: People in a city cross in front of traffic.
# Caption 4: Traffic in New York City during the day.
# Caption 5: Cars stopped on a busy street while pedestrians cross.
#
# Image URL: http://images.cocodataset.org/train2017/000000032203.jpg
# Caption 1: There are some dirt bike riders taking a sharp turn
# Caption 2: Dirt bikers racing around a corner on the track
# Caption 3: Motor bike racers race each other around a track.
# Caption 4: Dirt bike racers rounding a corner on a track with orange barriers
# Caption 5: Three people on motorbikes racing around a track.
#
# Image URL: http://images.cocodataset.org/train2017/000000525971.jpg
# Caption 1: A large group of motorcycle riders collect in a parking lot.
# Caption 2: A street full of motorcycles and their riders
# Caption 3: Several bikers are lined up in a parking lot.
# Caption 4: Motorcyclist meeting with one another before a ride.
# Caption 5: There is no picture or image sorry sorry
#
# Image URL: http://images.cocodataset.org/train2017/000000354572.jpg
# Caption 1: People sitting under an umbrella looking at the scenery.
# Caption 2: A person with a colorful umbrella sits on a fountain.
# Caption 3: A man with a colored umbrella sits on a monument.
# Caption 4: A man sis on a public area while holding an umbrella.
# Caption 5: This is a photo of two people sitting on the ledge of a piece of city artwork.
#
# Image URL: http://images.cocodataset.org/train2017/000000185360.jpg
# Caption 1: A cow standing next to a damaged car on a dirty lot.
# Caption 2: A broken down car being investigated by a cow.
# Caption 3: A cow stands in the mud next to a car.
# Caption 4: An abandoned car and a cow on a field.
# Caption 5: A cow standing by a damaged car in a field.
#
# Image URL: http://images.cocodataset.org/train2017/000000321064.jpg
# Caption 1: A small wooden table covered with delicious vegetables.
# Caption 2: A dining table with a bowl of garlic cloves.
# Caption 3: A kitchen table with a juicer and vegetable on it.
# Caption 4: A kitchen table with vegetables and food processor.
# Caption 5: A food processor sit on a small table in a kitchen next to fresh vegetables and a colander of mushrooms.

# %%
print(f"\nTotal number of unique images: {len(captions_dict)}")
# Out:
# Total number of unique images: 118287

# %% [markdown]
# ## **Buid dataset with image_id, image_url, and 5 captions**

# %%
import json
import csv
from collections import defaultdict

def build_coco_csv(annotation_file, output_csv):
    # Load COCO annotations
    with open(annotation_file, 'r') as f:
        coco = json.load(f)

    # Map image_id to coco_url
    id_to_url = {img['id']: img['coco_url'] for img in coco['images']}

    # Collect captions per image_id
    image_captions = defaultdict(list)
    for ann in coco['annotations']:
        image_id = ann['image_id']
        image_captions[image_id].append(ann['caption'])

    # CSV
    with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['image_id', 'image_url', 'caption_1', 'caption_2', 'caption_3', 'caption_4', 'caption_5']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for image_id, captions in image_captions.items():
            if len(captions) >= 5:
                row = {
                    'image_id': image_id,
                    'image_url': id_to_url[image_id],
                    'caption_1': captions[0],
                    'caption_2': captions[1],
                    'caption_3': captions[2],
                    'caption_4': captions[3],
                    'caption_5': captions[4]
                }
                writer.writerow(row)

annotation_file = 'captions_train2017.json'
output_csv = 'coco_image_captions.csv'
build_coco_csv(annotation_file, output_csv)

# %% [markdown]
# ## **Build dataset with embeddings**

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import ast

# Load the dataset
csv_path = 'coco_image_captions.csv'
df = pd.read_csv(csv_path)

# Load the sentence transformer model
# model = SentenceTransformer('all-MiniLM-L6-v2') # 384 dimensions
model = SentenceTransformer('all-mpnet-base-v2') # 768 dimensions
# model = SentenceTransformer('bert-large-nli-mean-tokens') # 1024 dimensions
# model = SentenceTransformer('hli/lstm-qqp-sentence-transformer') # 2048 dimensions

# Function to encode and average 5 captions
def get_avg_embedding(row):
    captions = [row[f'caption_{i}'] for i in range(1, 6)]
    embeddings = model.encode(captions)
    avg_embedding = np.mean(embeddings, axis=0)
    return avg_embedding.tolist()  # Convert to list for CSV compatibility

# Apply to each row
df['avg_caption_embedding'] = df.apply(get_avg_embedding, axis=1)

output_path = 'coco_with_embeddings.csv'
df.to_csv(output_path, index=False)

# %%
model = SentenceTransformer('all-mpnet-base-v2')
sentence = "This is a test sentence."
embeddings = model.encode(sentence)
embedding_size = embeddings.shape[0]

print(f'The embedding size is: {embedding_size}')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# The embedding size is: 768

# %%
df = pd.read_csv('coco_with_embeddings_768.csv')

# %%
df.head()
# Out:
#    image_id                                          image_url  \
# 0    203564  http://images.cocodataset.org/train2017/000000...
# 1    322141  http://images.cocodataset.org/train2017/000000...
# 2     16977  http://images.cocodataset.org/train2017/000000...
# 3    106140  http://images.cocodataset.org/train2017/000000...
# 4    571635  http://images.cocodataset.org/train2017/000000...
#
#                                            caption_1  \
# 0  A bicycle replica with a clock as the front wh...
# 1  A room with blue walls and a white sink and door.
# 2  A car that seems to be parked illegally behind...
# 3  A large passenger airplane flying through the ...
# 4        A bathroom with a toilet, sink, and shower.
#
#                                            caption_2  \
# 0                    The bike has a clock as a tire.
# 1   Blue and white color scheme in a small bathroom.
# 2      two cars parked on the sidewalk on the street
# 3  There is a GOL plane taking off in a partly cl...
# 4      A full bathroom with a wicker laundry basket.
#
#                                            caption_3  \
# 0  A black metal bicycle with a clock inside the ...
# 1  This is a blue and white bathroom with a wall ...
# 2          City street with parked cars and a bench.
# 3  An airplane that is, either, landing or just t...
# 4  A little bathrood decorated with many colorful...
#
#                                            caption_4  \
# 0  A bicycle figurine in which the front wheel is...
# 1  A blue boat themed bathroom with a life preser...
# 2  Cars try to maneuver into parking spaces along...
# 3    An red and white airplane is in the cloudy sky.
# 4    A small bathroom containing a toilet and sink.
#
#                                            caption_5  \
# 0  A clock with the appearance of the wheel of a ...
# 1  A bathroom with walls that are painted baby blue.
# 2  A couple of cars parked in a busy street sidew...
# 3        A passenger plane taking off into the sky.
# 4  Bathroom containing a toilet, a sink and a wic...
#
#                                avg_caption_embedding
# 0  [-0.0007135845953598619, 0.002707877429202199,...
# 1  [0.022635236382484436, -0.018114957958459854, ...
# 2  [0.004483063705265522, -0.004469511564821005, ...
# 3  [0.0016963969683274627, 0.024761024862527847, ...
# 4  [0.0051090167835354805, -0.014415529556572437,...

# %%
columns_to_drop = [f'caption_{i}' for i in range(1, 6)] + ['image_url']
df_reduced = df.drop(columns=columns_to_drop)
df_reduced.head()
# Out:
#    image_id                              avg_caption_embedding
# 0    203564  [-0.0007135845953598619, 0.002707877429202199,...
# 1    322141  [0.022635236382484436, -0.018114957958459854, ...
# 2     16977  [0.004483063705265522, -0.004469511564821005, ...
# 3    106140  [0.0016963969683274627, 0.024761024862527847, ...
# 4    571635  [0.0051090167835354805, -0.014415529556572437,...

# %%
import pandas as pd

total_rows = len(df_reduced)
chunk_size = total_rows // 3

for i in range(3):
    start = i * chunk_size
    end = (i + 1) * chunk_size if i < 2 else total_rows  
    chunk = df_reduced.iloc[start:end]
    chunk.to_parquet(f'coco_embeddings_768_part_{i+1}.parquet', index=False)

# %% [markdown]
# TODO:
# - Get RAM code
# - Modify RAM code to extract tags + confidence score (threshold)
# - Combine tags + confidence score with embeddings as the final dataset
